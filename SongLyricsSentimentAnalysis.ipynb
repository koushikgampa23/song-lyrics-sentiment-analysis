# %%
import pandas as pd
import string
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import nltk
import nltk.data
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import word_tokenize
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\koushikg\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\koushikg\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\koushikg\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\koushikg\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df1=pd.read_csv("ArianaGrande.csv")
df2=pd.read_csv("Beyonce.csv")
df2 = df2.drop('Unnamed: 0', axis=1)
df=[df1,df2]
df[1]
# Out:
#       Artist                             Title             Album    Year  \
# 0    Beyoncé                     Drunk in Love           BEYONCÉ  2013.0
# 1    Beyoncé                         Formation          Lemonade  2016.0
# 2    Beyoncé                         Partition           BEYONCÉ  2013.0
# 3    Beyoncé                              Mine           BEYONCÉ  2013.0
# 4    Beyoncé                           Hold Up          Lemonade  2016.0
# ..       ...                               ...               ...     ...
# 401  Beyoncé  Smash Into You (Lost Daze Remix)         Heat - EP     NaN
# 402  Beyoncé              Black Parade (Remix)               NaN     NaN
# 403  Beyoncé                         This Love               NaN     NaN
# 404  Beyoncé       At Last (Karmatronic Remix)         Heat - EP     NaN
# 405  Beyoncé       Sweet Dreams (OK DAC Remix)  Above and Beyond  2009.0
#
#            Date                                              Lyric
# 0    2013-12-17  beyoncé i've been drinkin' i've been drinkin' ...
# 1    2016-02-06  messy mya what happened at the new wil'ins bit...
# 2    2013-12-13  part  yoncé   let me hear you say hey ms carte...
# 3    2013-12-13  beyoncé i've been watching for the signs took ...
# 4    2016-04-23  hold up they don't love you like i love you sl...
# ..          ...                                                ...
# 401         NaN  head down as i watch my feet take turns hittin...
# 402         NaN  being black maybe that the reason why they alw...
# 403         NaN  lyrics for this song have yet to be released p...
# 404         NaN  at last my love has come along my lonely days ...
# 405  2009-01-06  every night i rush to my bed with hopes that m...
#
# [406 rows x 6 columns]
